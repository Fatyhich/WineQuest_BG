# %%
import pandas as pd
import torch
import torch.nn.functional as F

from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModel


class RecommenderService:

    _TASK = "Find similar wine descriptions"

    def __init__(self):
        raw_data = pd.read_csv("wines_new.csv")
        wine_columns = list(raw_data.columns)
        df = raw_data[wine_columns][raw_data['Тип продукта']!='Оливковое масло'].copy()
        desc_col = wine_columns[2:]
        for col in desc_col:
            df[col] = df[col].astype(str).fillna("")
            
        df['Описание вина'] = df.apply(lambda row: ". ".join([f"{col} - {row[col]}"
                                                      for col in desc_col]), axis=1)
        self._df = df
        self._texts = df["Описание вина"].tolist()

        self._tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-large-instruct')
        self._model = AutoModel.from_pretrained('intfloat/multilingual-e5-large-instruct')

        self._wine_vectors = torch.load('wine_vectors.pt')

    def recommend(self, query: str, mode: str) -> str:
        user_query = query
        formatted_query = self.get_detailed_instruct(self._TASK, user_query)

        # Tokenize the user query
        query_inputs = self._tokenizer(formatted_query, max_length=512,
                                padding=True, truncation=True, return_tensors='pt')

        # Generate embeddings for the query
        with torch.no_grad():
            query_outputs = self._model(**query_inputs)

        # Pool and normalize the query embeddings
        query_embeddings = self.average_pool(query_outputs.last_hidden_state,
                                        query_inputs['attention_mask'])
        query_vector = F.normalize(query_embeddings, p=2, dim=1).squeeze()

        # Calculate similarities (assuming wine_vectors are already normalized)
        similarities = torch.matmul(query_vector, torch.stack(self._wine_vectors).T)

        # Find top-N similar wines
        top_n = 5
        top_indices = torch.topk(similarities, top_n).indices.tolist()

        # Extract matching wines
        best_wines = self._df.iloc[top_indices].to_json(orient='records', force_ascii=False)

        return best_wines

    def average_pool(self, last_hidden_states: torch.Tensor,
                 attention_mask: torch.Tensor) -> torch.Tensor:
        last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
        return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

    def get_detailed_instruct(self, task_description: str, query: str) -> str:
        return f'Instruct: {task_description}\nQuery: {query}'

# %%
srv = RecommenderService()
# Out:
# /tmp/ipykernel_3943967/2865953990.py:29: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self._wine_vectors = torch.load('wine_vectors.pt')

# %%
result = srv.recommend("красное вино к индейке не из италии", "audio")

# %%
result = json.loads(result)

# %%
result
# Out:
# [{'Название': 'Cheval des Andes, Mendoza',
#   'Ссылка': 'https://verigo.ru/product/cheval-des-andes-mendoza',
#   'Цена': '25 450 ₽',
#   'Тип продукта': 'Вино',
#   'Страна': 'Аргентина',
#   'Содержание сахара': 'сухое',
#   'Цвет': 'Интенсивного блестящего красного цвета с\xa0 фиолетовыми оттенками.',
#   'Регион': 'Мендоса',
#   'Объем, л': '0,75',
#   'Сорт винограда': 'Каберне Совиньон; Мальбек; Пти Вердо',
#   'Классификация': 'Mendoza',
#   'Крепость': '14,5%',
#   'Бренд': 'Fine Wine',
#   'Рейтинги': 'nan',
#   'Аромат': 'В богатом аромате можно почувствовать нотки\xa0 вишни и дикой клубники. Перечные нотки ярко\xa0 чувствуются, подчёркивая строгость вина.',
#   'Цена': '1 690 ₽',
#   'Тип продукта': 'Вино',
#   'Страна': 'Франция',
#   'Содержание сахара': 'сухое',
#   'Цвет': 'Красивый красный цвет с фиолетовыми оттенками',
#   'Регион': 'Лангедок',
#   'Объем, л': '0,75',
#   'Сорт винограда': 'Мерло',
#   'Классификация': "IGP Pays d'Oc",
#   'Крепость': '13%',
#   'Бренд': 'Bree',
#   'Рейтинги': 'nan',
#   'Аромат': 'Роскошное красное вино с ароматом лесных ягод.',
#   'Вкус': 'Мягкое и пряное, с выразительным вкусом и тонкой структурой.',
#   'Способ производства': 'nan',
#   'Гастрономия': 'Вино составит отличную пару пасте, телятине и красному мясу.',
#   'Награды': 'nan',
#   'Интересные факты': 'nan',
#   'Философия производства': 'nan',
#   'Год': 'nan',
#   'Подарочная упаковка': 'nan',
#   'Состав': 'nan',
#   'Кислотность': 'nan',
#   'Vivino': 'nan',
#   'Описание вина': "Цена - 1 690 ₽. Тип продукта - Вино. Страна - Франция. Содержание сахара - сухое. Цвет - Красивый красный цвет с фиолетовыми оттенками. Регион - Лангедок. Объем, л - 0,75. Сорт винограда - Мерло. Классификация - IGP Pays d'Oc. Крепость - 13%. Бренд - Bree. Рейтинги - nan. Аромат - Роскошное красное вино с ароматом лесных ягод.. Вкус - Мягкое и пряное, с выразительным вкусом и тонкой структурой.. Способ производства - nan. Гастрономия - Вино составит отличную пару пасте, телятине и красному мясу.. Награды - nan. Интересные факты - nan. Философия производства - nan. Год - nan. Подарочная упаковка - nan. Состав - nan. Кислотность - nan. Vivino - nan"},
#  {'Название': 'Tussock Jumper Cabernet Sauvignon, San Juan',
#   'Ссылка': 'https://verigo.ru/product/tussock-jumper-cabernet-sauvignon',
#   'Цена': '1 590 ₽',
#   'Тип продукта': 'Вино',
#   'Страна': 'Аргентина',
#   'Содержание сахара': 'сухое',
#   'Цвет': 'Интенсивный красный цвет.',
#   'Регион': 'Сан Хуан',
#   'Объем, л': '0,75',
#   'Сорт винограда': 'Каберне Совиньон',
#   'Классификация': 'San Juan',
#   'Крепость': '13,5%',
#   'Бренд': 'Tussock Jumper',
#   'Рейтинги': 'vivino 3.8',
#   'Аромат': 'Свежий фруктовый аромат с пряными нотками, придающими сложность.',
#   'Вкус': 'Вкус приятный, сладковатый с нотами спелых фруктов, нежный, с мягкими и округлыми танинами. Нежные и приятное послевкусие.',
#   'Способ производства': 'Предварительная мацерация при температуре 12ºC в течение 48 часов. Затем\xa0 ферментация при температуре от 23°C до 26°C в течение 9 дней с добавлением отборных дрожжей. 30% выдерживается в дубе в течение 3 месяцев (половина французский дуб, половина - американский).',
#   'Гастрономия': 'Вино идеально сочетается с мясными блюдами, пастой, пиццей, а также мексиканской кухней.',
#   'Награды': 'Gold Medal China Wine & Spirits Awards 2020Gold Medal China Wine & Spirits Awards 2019',
#   'Интересные факты': 'Сан Хуан - второй по площади и значимости винный регион Аргентины, виноградники занимают около 50 тыс. гектар. Холодные ночи и жаркие дни позволяют получать фруктовые красные вина с интенсивной ароматикой.',
#   'Философия производства': 'nan',
#   'Год': 'nan',
#   'Подарочная упаковка': 'nan',
#   'Состав': 'nan',
#   'Кислотность': 'nan',
#   'Vivino': 'nan',
#   'Описание вина': 'Цена - 1 590 ₽. Тип продукта - Вино. Страна - Аргентина. Содержание сахара - сухое. Цвет - Интенсивный красный цвет.. Регион - Сан Хуан. Объем, л - 0,75. Сорт винограда - Каберне Совиньон. Классификация - San Juan. Крепость - 13,5%. Бренд - Tussock Jumper. Рейтинги - vivino 3.8. Аромат - Свежий фруктовый аромат с пряными нотками, придающими сложность.. Вкус - Вкус приятный, сладковатый с нотами спелых фруктов, нежный, с мягкими и округлыми танинами. Нежные и приятное послевкусие.. Способ производства - Предварительная мацерация при температуре 12ºC в течение 48 часов. Затем\xa0 ферментация при температуре от 23°C до 26°C в течение 9 дней с добавлением отборных дрожжей. 30% выдерживается в дубе в течение 3 месяцев (половина французский дуб, половина - американский).. Гастрономия - Вино идеально сочетается с мясными блюдами, пастой, пиццей, а также мексиканской кухней.. Награды - Gold Medal China Wine & Spirits Awards 2020Gold Medal China Wine & Spirits Awards 2019. Интересные факты - Сан Хуан - второй по площади и значимости винный регион Аргентины, виноградники занимают около 50 тыс. гектар. Холодные ночи и жаркие дни позволяют получать фруктовые красные вина с интенсивной ароматикой.. Философия производства - nan. Год - nan. Подарочная упаковка - nan. Состав - nan. Кислотность - nan. Vivino - nan'},
#  {'Название': 'Tussock Jumper Carmenere, Colchagua Valley',
#   'Ссылка': 'https://verigo.ru/product/tassok-dzhamper-karmener',
#   'Цена': '1 440 ₽',
#   'Тип продукта': 'Вино',
#   'Страна': 'Чили',
#   'Содержание сахара': 'сухое',
#   'Цвет': 'Насыщенный красно-рубиновый цвет.',
#   'Регион': 'Долина Кольчагуа',
#   'Объем, л': '0,75',
#   'Сорт винограда': 'Карменер',
#   'Классификация': 'Colchagua Valley',
#   'Крепость': '14%',
#   'Бренд': 'Tussock Jumper',
#   'Рейтинги': 'vivino 3.7',
#   'Аромат': 'Аромат с нотами нот черных и красных ягод и едва уловимых оттенков табака.',
#   'Вкус': 'Мощный, богатый, великолепно сбалансированный вкус с хорошей кислотностью, мягкими танинами и нюансами вишни и ежевики в долгом послевкусии.',
#   'Способ производства': 'Традиционная винификация.',
#   'Гастрономия': 'Идеально сочетается с красным мясом ягненка с кисло-сладким сливовым соусом с жареным картофелем.',
#   'Награды': 'nan',
#   'Интересные факты': '80% всех мировых посадок карменера приходится именно на Чили. 24 ноября отмечается Международный день карменера.',
#   'Философия производства': 'nan',
#   'Год': 'nan',
#   'Подарочная упаковка': 'nan',
#   'Состав': 'nan',
#   'Кислотность': 'nan',
#   'Vivino': 'nan',
